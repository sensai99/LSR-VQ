# %%
# !pip install transformers
# !pip install datasets
# !pip install --upgrade accelerate
# !pip install rank-eval
# !pip install ranx
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 10.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 103.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting rank-eval
#   Downloading rank_eval-0.1.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rank-eval) (2.0.2)
# Requirement already satisfied: numba>=0.54.1 in /usr/local/lib/python3.11/dist-packages (from rank-eval) (0.60.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from rank-eval) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from rank-eval) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from rank-eval) (4.67.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54.1->rank-eval) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->rank-eval) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->rank-eval) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->rank-eval) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->rank-eval) (1.17.0)
# Downloading rank_eval-0.1.3-py3-none-any.whl (17 kB)
# Installing collected packages: rank-eval
# Successfully installed rank-eval-0.1.3
# Collecting ranx
#   Downloading ranx-0.3.20-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ranx) (2.0.2)
# Requirement already satisfied: numba>=0.54.1 in /usr/local/lib/python3.11/dist-packages (from ranx) (0.60.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ranx) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from ranx) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from ranx) (4.67.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ranx) (1.15.2)
# Collecting ir-datasets (from ranx)
#   Downloading ir_datasets-0.5.10-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from ranx) (13.9.4)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from ranx) (3.10.17)
# Collecting lz4 (from ranx)
#   Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting cbor2 (from ranx)
#   Downloading cbor2-5.6.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from ranx) (0.13.2)
# Collecting fastparquet (from ranx)
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54.1->ranx) (0.43.0)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet->ranx) (2.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet->ranx) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet->ranx) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ranx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ranx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ranx) (2025.2)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx) (4.13.4)
# Collecting inscriptis>=2.2.0 (from ir-datasets->ranx)
#   Downloading inscriptis-2.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx) (5.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx) (6.0.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx) (2.32.3)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets->ranx)
#   Downloading trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting warc3-wet>=0.2.3 (from ir-datasets->ranx)
#   Downloading warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets->ranx)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3 (from ir-datasets->ranx)
#   Downloading zlib_state-0.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting ijson>=3.1.3 (from ir-datasets->ranx)
#   Downloading ijson-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets->ranx)
#   Downloading unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pyarrow>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx) (18.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->ranx) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->ranx) (2.19.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn->ranx) (3.10.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets->ranx) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets->ranx) (4.13.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->ranx) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ranx) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx) (2025.4.26)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets->ranx)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Downloading ranx-0.3.20-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/99.3 kB 3.9 MB/s eta 0:00:00
# Downloading cbor2-5.6.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 10.1 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 43.7 MB/s eta 0:00:00
# Downloading ir_datasets-0.5.10-py3-none-any.whl (859 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.0/859.0 kB 52.7 MB/s eta 0:00:00
# Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.2 MB/s eta 0:00:00
# Downloading ijson-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 10.2 MB/s eta 0:00:00
# Downloading inscriptis-2.6.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 4.0 MB/s eta 0:00:00
# Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Downloading unlzw3-0.2.3-py3-none-any.whl (6.7 kB)
# Downloading warc3_wet-0.2.5-py3-none-any.whl (18 kB)
# Downloading zlib_state-0.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Building wheels for collected packages: warc3-wet-clueweb09, cbor
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=35f3d18987a18117df526a50d9a5b166d8e51fa34ba0a472b444eec15d5636a5
#   Stored in directory: /root/.cache/pip/wheels/63/f9/dc/2dd16d3330e327236e4d407941975c42d5159d200cdb7922d8
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp311-cp311-linux_x86_64.whl size=53932 sha256=f1676d346f279360991e066da9150fe188325d42687b41597d8067d88907e5ec
#   Stored in directory: /root/.cache/pip/wheels/21/6b/45/0c34253b1af07d1d9dc524f6d44d74a6b191c43152e6aaf641
# Successfully built warc3-wet-clueweb09 cbor
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, ijson, cbor, zlib-state, unlzw3, trec-car-tools, lz4, cbor2, inscriptis, ir-datasets, fastparquet, ranx
# Successfully installed cbor-1.0.0 cbor2-5.6.5 fastparquet-2024.11.0 ijson-3.3.0 inscriptis-2.6.0 ir-datasets-0.5.10 lz4-4.4.4 ranx-0.3.20 trec-car-tools-2.6 unlzw3-0.2.3 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 zlib-state-0.1.9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from transformers import AutoModel, AutoTokenizer, Trainer, TrainingArguments, DataCollatorWithPadding
from datasets import Dataset
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm.autonotebook import trange
import numpy as np
import json
import random
from torch.utils.data import DataLoader, RandomSampler
from tqdm import tqdm
from ranx import Qrels, Run, evaluate

# %%
import os
import gc

# %%
import sys
sys.path.append('/content/drive/MyDrive/685/code')
from utils import tsv_to_dict_multiple, tsv_to_dict_unqiue

# %%
model = None
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Fri May  2 03:49:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             51W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Load raw training data

# %%
# base-model
# model_name = 'facebook/contriever'
# fine-tuned MS-MARCO
model_name = "facebook/contriever-msmarco"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/321 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
passages = tsv_to_dict_unqiue(os.path.join('/content/drive/MyDrive/685/data', "collection.tsv"))
queries = tsv_to_dict_unqiue(os.path.join('/content/drive/MyDrive/685/data', "queries.train.tsv"))

# %%
def create_dataset(address, n_negatives=2,cache_dir='hf',sample_count=1000):
    def train_gen():
      with open(address,'r') as f:
          count = 0
          for line in f:
              count += 1
              if sample_count != None and count >= sample_count: return
              data_sample = json.loads(line)
              negatives = []
              for neg_id in random.sample(data_sample['neg']['bm25'],n_negatives): negatives.append(passages[str(neg_id)])
              yield {'query': queries[str(data_sample['qid'])],'positive':passages[str(random.sample(data_sample['pos'],1)[0])],'negatives':negatives}
    return Dataset.from_generator(train_gen, cache_dir = cache_dir)

# %%
dataset = create_dataset(os.path.join('/content/drive/MyDrive/685/data','msmarco-hard-negatives-bm25_1k.jsonl'), 2, 'hf',2000)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
split_dataset = dataset.train_test_split(test_size=0.1)

# There might be a split over
train_dataset = split_dataset['train']
eval_dataset = split_dataset['test']

# %% [markdown]
# ### Custom data collator

# %%
from typing import Any, Dict, List, Union

class CustomDataCollatorWithPadding(DataCollatorWithPadding):
    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, torch.Tensor]:
        query_texts = []
        pos_texts = []
        neg_texts = []

        for feature in features:
            query_texts.append(feature['query'])
            pos_texts.append(feature['positive'])
            if 'negatives' in feature.keys():
                for neg_text in feature['negatives']: neg_texts.append(neg_text)

        tokenized_query_texts = self.tokenizer(
                query_texts,
                max_length=self.max_length,
                padding=self.padding,
                truncation=True,
                return_tensors="pt",
                add_special_tokens=True)

        tokenized_pos_texts = self.tokenizer(
                pos_texts,
                max_length=self.max_length,
                padding=self.padding,
                truncation=True,
                return_tensors="pt",
                add_special_tokens=True)

        tokenized_texts = {
            'tokenized_queries' : tokenized_query_texts,
            'tokenized_positives' : tokenized_pos_texts,
        }


        if len(neg_texts) > 0:
            tokenized_neg_texts = self.tokenizer(
                  neg_texts,
                  max_length=self.max_length,
                  padding=self.padding,
                  truncation=True,
                  return_tensors="pt",
                  add_special_tokens=True)
            tokenized_texts['tokenized_negatives'] = tokenized_neg_texts

        return tokenized_texts

custom_data_collator = CustomDataCollatorWithPadding(
    tokenizer=tokenizer,
    padding='longest',
    max_length=tokenizer.model_max_length
)

# %%
out_train = custom_data_collator([train_dataset[i] for i in range(8)])
print(out_train['tokenized_queries']['input_ids'].shape)
print(out_train['tokenized_positives']['input_ids'].shape)
print(out_train['tokenized_negatives']['input_ids'].shape)
# Out:
# torch.Size([8, 9])
# torch.Size([8, 160])
# torch.Size([16, 162])

# %%
out_eval = custom_data_collator([eval_dataset[i] for i in range(2)])
print(out_eval['tokenized_queries']['input_ids'].shape)
print(out_eval['tokenized_positives']['input_ids'].shape)
# Out:
# torch.Size([2, 7])
# torch.Size([2, 81])

# %% [markdown]
# ### Contrastive loss

# %%
#enter your code here
def get_contriever_emb(model_output, attention_mask):
    last_hidden = model_output
    last_hidden = last_hidden.masked_fill(~attention_mask[..., None].bool(), 0.0)
    emb = last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]
    return emb

def contrastive_loss(query_embs,pos_embs,neg_embs):
    temp = 0.05
    query_embs = query_embs/temp
    similarities_pos = torch.mm(query_embs,torch.transpose(pos_embs,0,1))
    similarities = similarities_pos
    if neg_embs != None:
        similarities_neg = torch.mm(query_embs,torch.transpose(neg_embs,0,1))
        similarities = torch.cat((similarities_pos,similarities_neg),dim=1)
    return F.cross_entropy(similarities,torch.arange(0,query_embs.shape[0]).to('cuda'))

# def contrastive_loss(query_embs, pos_embs, neg_embs=None, temperature=0.05):
#     device = query_embs.device
#     #Only the queries are temperature-scaled. Both query and key (positive/negative) should ideally be scaled
#     query_embs = query_embs / temperature
#     pos_embs = pos_embs / temperature

#     sim_pos = torch.mm(query_embs, pos_embs.T)

#   #If your negatives are reused from another forward pass, they might retain gradients accidentally. Best to detach.
#     if neg_embs is not None:
#         neg_embs = neg_embs.detach() / temperature  # Prevent gradient through negatives
#         sim_neg = torch.mm(query_embs, neg_embs.T)
#         logits = torch.cat([sim_pos, sim_neg], dim=1)
#     else:
#         logits = sim_pos

#     targets = torch.arange(query_embs.size(0), device=device)
#     loss = F.cross_entropy(logits, targets)
#     return loss

# %% [markdown]
# ### Models

# %%
class Quantize(nn.Module):
    def __init__(self, codebook_vector_dim, num_clusters, decay = 0.99, eps = 1e-5):
        super().__init__()

        self.dim = codebook_vector_dim
        self.num_clusters = num_clusters
        self.decay = decay
        self.eps = eps

        embed = torch.randn(codebook_vector_dim, num_clusters)
        self.register_buffer("embed", embed)
        self.register_buffer("cluster_size", torch.zeros(num_clusters))
        self.register_buffer("embed_avg", embed.clone())

    def forward(self, input, training = True):
        input = torch.nn.functional.normalize(input, p=2, dim=1)
        flatten = input.reshape(-1, self.dim)
        dist = (
            flatten.pow(2).sum(1, keepdim = True)
            - 2 * flatten @ self.embed
            + self.embed.pow(2).sum(0, keepdim = True)
        )
        _, embed_ind = (-dist).max(1)
        embed_onehot = F.one_hot(embed_ind, self.num_clusters).type(flatten.dtype)
        embed_ind = embed_ind.view(*input.shape[:-1])
        quantize = self.embed_code(embed_ind)

        if training:
            embed_onehot_sum = embed_onehot.sum(0)
            embed_sum = flatten.transpose(0, 1) @ embed_onehot

            self.cluster_size.data.mul_(self.decay).add_(
                embed_onehot_sum, alpha=1 - self.decay
            )
            self.embed_avg.data.mul_(self.decay).add_(embed_sum, alpha=1 - self.decay)
            n = self.cluster_size.sum()
            cluster_size = (
                (self.cluster_size + self.eps) / (n + self.num_clusters * self.eps) * n
            )
            embed_normalized = self.embed_avg / cluster_size.unsqueeze(0)
            self.embed.data.copy_(embed_normalized)

        quantize = input + (quantize - input).detach()
        return quantize, embed_ind

    def embed_code(self, embed_id):
        return F.embedding(embed_id, self.embed.transpose(0, 1))

# %%
class Sparse_Layer(nn.Module):
    def __init__(self,d,D):
        super().__init__()

        self.up_projection = nn.Linear(d,D)
        nn.init.xavier_uniform_(self.up_projection.weight)
        nn.init.zeros_(self.up_projection.bias)


    # def forward(self,embeds):
    #     # Normalize input to prevent large values
    #     embeds = torch.nn.functional.normalize(embeds, p=2, dim=1)

    #     print("NaNs before matmul:", torch.isnan(embeds).any())
    #     S = self.up_projection(embeds)
    #     print("NaNs after projection:", torch.isnan(S).any())
    #     # S = torch.log(1 + torch.relu(S))
    #     # S = torch.log1p(F.relu(S))
    #     # print("NaNs after logrelu:", torch.isnan(S).any())
    #     # S = torch.clamp(S, max=10)
    #     S = torch.clamp(F.relu(S), max=100)  # Clamp before log1p to avoid NaNs from large values
    #     print("NaNs after clamp:", torch.isnan(S).any())
    #     S = torch.log1p(S)
    #     print("NaNs after logrelu:", torch.isnan(S).any())
    #     # print("NaNs after clamp:", torch.isnan(S).any())
    #     S = torch.nn.functional.normalize(S, p=2, dim=1,eps=1e-8)
    #     print("NaNs after normalize:", torch.isnan(S).any())
    #     return S

    def forward(self, embeds):
        # Normalize input embeddings to unit norm
        embeds = torch.nn.functional.normalize(embeds, p=2, dim=1)

        # print("NaNs before projection:", torch.isnan(embeds).any())

        # Step 2: Apply linear projection
        S = self.up_projection(embeds)
        # print("NaNs after projection:", torch.isnan(S).any())

        # Step 3: Apply ReLU to keep only positive activations
        S = F.relu(S)

        # Step 4: Clamp large activations before log1p to avoid NaNs from log(Inf)
        S = torch.clamp(S, max=100)
        # print("NaNs after clamp:", torch.isnan(S).any())

        # Step 5: Apply log1p to compress dynamic range
        S = torch.log1p(S)
        # print("NaNs after log1p:", torch.isnan(S).any())

        # Step 6: Final normalization to ensure stable gradient flow
        S = torch.nn.functional.normalize(S, p=2, dim=1, eps=1e-8)
        # print("NaNs after final normalize:", torch.isnan(S).any())

        return S

# %%
class LSR_VQ(nn.Module):
    def __init__(self, model_name, emb_dim, num_clusters, d, D, freeze_contriver=False):
        super().__init__()
        self.model = AutoModel.from_pretrained(model_name,device_map='auto')
        if freeze_contriver:
            for param in self.model.parameters():
                param.requires_grad = False
        self.quantizer = Quantize(emb_dim,num_clusters)
        self.sparse_layer = Sparse_Layer(d,D)

    def forward(self, inputs):
        query_embs = self.model(**inputs['tokenized_queries']).last_hidden_state
        query_dense = get_contriever_emb(query_embs,inputs['tokenized_queries']['attention_mask'])

        pos_embs = self.model(**inputs['tokenized_positives']).last_hidden_state
        pos_dense = get_contriever_emb(pos_embs,inputs['tokenized_positives']['attention_mask'])

        neg_embs = self.model(**inputs['tokenized_negatives']).last_hidden_state
        neg_dense = get_contriever_emb(neg_embs,inputs['tokenized_negatives']['attention_mask'])

        quantized_embs, _ = self.quantizer(torch.cat([query_dense,pos_dense,neg_dense],dim=0),True)

        query_offset = 0
        pos_offset = query_dense.shape[0]
        neg_offset = query_dense.shape[0] + pos_dense.shape[0]

        query_quantized_embs = quantized_embs[:pos_offset]
        pos_quantized_embs = quantized_embs[pos_offset:neg_offset]
        neg_quantized_embs = quantized_embs[neg_offset:]

        query_sparse = self.sparse_layer(query_quantized_embs)
        pos_sparse = self.sparse_layer(pos_quantized_embs)
        neg_sparse = self.sparse_layer(neg_quantized_embs)

        return query_dense,query_sparse,pos_dense,pos_sparse,neg_dense,neg_sparse

    def get_sparse_rep(self,input_ids,attention_mask):
        # embs = self.model(input_ids)
        embs = self.model(input_ids=input_ids, attention_mask=attention_mask).last_hidden_state
        dense_embs = get_contriever_emb(embs,attention_mask)

        quantized_embs, codes = self.quantizer(dense_embs,False)

        sparse_rep = self.sparse_layer(quantized_embs)

        return sparse_rep

# %%
model = LSR_VQ(model_name,768,2048,768,8192)
# Out:
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %% [markdown]
# ### Training

# %%
#enter your code here to define trainer
class LSRVQ_Trainer(Trainer):

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.query_reg_lambda = 0.1
        self.passage_reg_lambda = 0.1

    def compute_loss(self, model, inputs, return_outputs=False,num_items_in_batch=None):

        query_dense, query_sparse, pos_dense, pos_sparse, neg_dense, neg_sparse = self.model(inputs)

        # Detach negatives to avoid unintended gradient retention
        if neg_dense is not None:
            neg_dense = neg_dense.detach()

        # Constrastive loss
        c_loss = contrastive_loss(query_dense,pos_dense,neg_dense)

        print('c_loss',c_loss)

        # Query sparsity loss
        # query_reg_loss = torch.sum(torch.mean(torch.abs(query_sparse), dim=0) ** 2)
        query_reg_loss = torch.mean(torch.abs(query_sparse))
        print('q_loss',query_reg_loss)

        # Document sparsity loss
        passage_sparse = torch.cat([pos_sparse,neg_sparse], dim=0)
        # passage_reg_loss = torch.sum(torch.mean(torch.abs(passage_sparse), dim=0) ** 2)
        passage_reg_loss = torch.mean(torch.abs(passage_sparse))

        print('p_loss',passage_reg_loss)

        loss = c_loss + self.query_reg_lambda*query_reg_loss + self.passage_reg_lambda*passage_reg_loss

        return (loss,torch.zeros(1)) if return_outputs else loss

# %%
training_args = TrainingArguments(
    output_dir="./weights",
    overwrite_output_dir=True,
    num_train_epochs=4,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    warmup_steps=0,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    eval_steps=5,
    eval_strategy="steps",
    save_total_limit=36,
    save_steps=5,
    load_best_model_at_end=True,
    greater_is_better=False,
    learning_rate=1e-4,
    lr_scheduler_type = "linear",
    fp16=True,
    report_to='none',
    metric_for_best_model="eval_loss",
    remove_unused_columns=False,
    # optim = "adamw_8bit",
)

# %%
trainer = LSRVQ_Trainer(
        model = model,
        args = training_args,
        data_collator = custom_data_collator,
        train_dataset = train_dataset,
        eval_dataset = eval_dataset)

trainer.can_return_loss=True

def custom_eval_dataloader(eval_set):
    return DataLoader(
    eval_set,
    batch_size=training_args.eval_batch_size,
    sampler=RandomSampler(eval_dataset),
    collate_fn=trainer.data_collator,
)

trainer.get_eval_dataloader = custom_eval_dataloader

# %%
trainer.train()
# Out:
# c_loss tensor(0.1271, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
#     <div>
#
#       <progress value='228' max='228' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [228/228 03:18, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.124200</td>
#       <td>0.258736</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.108800</td>
#       <td>1.933208</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.247200</td>
#       <td>1.900115</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.141600</td>
#       <td>2.169508</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.667200</td>
#       <td>1.274425</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.022900</td>
#       <td>1.374936</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.296400</td>
#       <td>0.852485</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.541900</td>
#       <td>0.782983</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.218400</td>
#       <td>0.849580</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.779900</td>
#       <td>0.484162</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.425700</td>
#       <td>0.386809</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.462200</td>
#       <td>0.521277</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.712000</td>
#       <td>1.047332</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.498600</td>
#       <td>0.641855</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.367200</td>
#       <td>0.479116</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.483600</td>
#       <td>0.621517</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.499000</td>
#       <td>0.431009</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.356800</td>
#       <td>0.384258</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.516400</td>
#       <td>0.331916</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.564800</td>
#       <td>0.409300</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.260700</td>
#       <td>0.281829</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.461800</td>
#       <td>0.332302</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.442500</td>
#       <td>0.365394</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.189100</td>
#       <td>0.283241</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.195300</td>
#       <td>0.292797</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.132500</td>
#       <td>0.558400</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.205000</td>
#       <td>0.386480</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.176200</td>
#       <td>0.562517</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.212700</td>
#       <td>0.605776</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.273200</td>
#       <td>0.544226</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.148400</td>
#       <td>0.473297</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.097000</td>
#       <td>0.524227</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.191000</td>
#       <td>0.759940</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.144700</td>
#       <td>1.032831</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.110300</td>
#       <td>1.056958</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.107800</td>
#       <td>0.748760</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.096600</td>
#       <td>1.031278</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.151000</td>
#       <td>0.701401</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.335500</td>
#       <td>0.838760</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.103800</td>
#       <td>0.785396</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.129700</td>
#       <td>1.048119</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.157900</td>
#       <td>0.772824</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.073600</td>
#       <td>0.964415</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.132000</td>
#       <td>0.804573</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.174500</td>
#       <td>0.767798</td>
#     </tr>
#   </tbody>
# </table><p>
# c_loss tensor(0.0627, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0403, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1231, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2614, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4155, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.1962, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(0.0666, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.5436, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(0.5185, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.0620, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(5.9605e-08, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(0.3554, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0850, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.1939, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.5423, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(2.3613, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.8096, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(5.2762, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.3706, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(4.0241, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(0.8739, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.1693, device='cuda:0')
# q_loss tensor(0.0064, device='cuda:0')
# p_loss tensor(0.0064, device='cuda:0')
# c_loss tensor(0., device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(2.2264, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0063, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(2.1200, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5533, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(3.5865, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(2.7436, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(4.2863, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.8240, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.7078, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.9671, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.7339, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(1.0294, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(2.7436, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.8377, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.5165, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(12.7476, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.7352, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(7.8646, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5531, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.9915, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(4.3232, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(3.1411, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.4458, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.7505, device='cuda:0')
# q_loss tensor(0.0063, device='cuda:0')
# p_loss tensor(0.0063, device='cuda:0')
# c_loss tensor(2.9726, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(3.7381, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.3466, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7943, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.6768, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7742, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.1129, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.5769, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(3.6922, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.6058, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.1899, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.7346, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0., device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.4287, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.2644, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7274, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.9517, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7362, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.7472, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.2389, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.0669, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.2385, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.6791, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.5010, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(5.1444, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(2.0196, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.9606, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.8398, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3598, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(2.2959, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1903, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.4945, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(2.1214, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.6076, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.4754, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(1.5008, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.5687, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(2.1205, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1643, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(2.0879, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.9385, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.3923, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.2992, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(1.1721, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.8261, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.1304, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.3120, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.7325, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.8402e-05, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.6288, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7621, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.6339, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6085, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(2.4524, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.9567, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.0393, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.1051, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(2.4186, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.4579, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.4965, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.4644, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.4105, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1725, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.0642, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.0139, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2320, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6078, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.0058, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.7468, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.2284, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.2747, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.5163, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.0008, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.4784, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3444, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6826, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.8102, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(4.8069, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6871, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.0100, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.3686, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.8894, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.2653, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.4620, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.0169, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.1029, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4535, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0130, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3608, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3747, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.8423, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.9033, device='cuda:0')
# q_loss tensor(0.0062, device='cuda:0')
# p_loss tensor(0.0062, device='cuda:0')
# c_loss tensor(0.2578, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.0172, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.9910, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.3914, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.2375, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(1.1705, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6058, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3200, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.8717, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5861, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7417, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(1.1069, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.9691, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(2.8451, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.9613, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.6447, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.0540, device='cuda:0')
# q_loss tensor(0.0059, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.4493, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2334, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.0198, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7845, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3715, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.4579, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.9906, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.3855, device='cuda:0')
# q_loss tensor(0.0059, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(2.0303, device='cuda:0')
# q_loss tensor(0.0061, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(0.2486, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0061, device='cuda:0')
# c_loss tensor(3.6354e-05, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.4850, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5777, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0061, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3862, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0586, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3225, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3809, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.6953, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.5336, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(1.0712, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.4136, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.2451, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.0056, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.8195, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2676, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1303, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6893, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5052, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.2871, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.3724, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.8691, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.5833, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.0510, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.5246, device='cuda:0')
# q_loss tensor(0.0059, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.6548, device='cuda:0')
# q_loss tensor(0.0060, device='cuda:0')
# p_loss tensor(0.0060, device='cuda:0')
# c_loss tensor(0.3027, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4727, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0121, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0060, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.3608, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3408, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4692, device='cuda:0')
# q_loss tensor(0.0058, device='cuda:0')
# p_loss tensor(0.0057, device='cuda:0')
# c_loss tensor(0.3918, device='cuda:0')
# q_loss tensor(0.0058, device='cuda:0')
# p_loss tensor(0.0058, device='cuda:0')
# c_loss tensor(1.4988, device='cuda:0')
# q_loss tensor(0.0058, device='cuda:0')
# p_loss tensor(0.0058, device='cuda:0')
# c_loss tensor(0.3895, device='cuda:0')
# q_loss tensor(0.0058, device='cuda:0')
# p_loss tensor(0.0058, device='cuda:0')
# c_loss tensor(0.1836, device='cuda:0')
# q_loss tensor(0.0059, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.0758, device='cuda:0')
# q_loss tensor(0.0059, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.0002, device='cuda:0')
# q_loss tensor(0.0059, device='cuda:0')
# p_loss tensor(0.0059, device='cuda:0')
# c_loss tensor(0.4228, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0059, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6369, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1073, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0058, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1630, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0057, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0057, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4483, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0056, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0056, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.0123, device='cuda:0')
# q_loss tensor(0.0054, device='cuda:0')
# p_loss tensor(0.0054, device='cuda:0')
# c_loss tensor(0.2579, device='cuda:0')
# q_loss tensor(0.0054, device='cuda:0')
# p_loss tensor(0.0054, device='cuda:0')
# c_loss tensor(0.0368, device='cuda:0')
# q_loss tensor(0.0054, device='cuda:0')
# p_loss tensor(0.0054, device='cuda:0')
# c_loss tensor(0.1041, device='cuda:0')
# q_loss tensor(0.0055, device='cuda:0')
# p_loss tensor(0.0055, device='cuda:0')
# c_loss tensor(0.9969, device='cuda:0')
# q_loss tensor(0.0055, device='cuda:0')
# p_loss tensor(0.0055, device='cuda:0')
# c_loss tensor(0.2096, device='cuda:0')
# q_loss tensor(0.0055, device='cuda:0')
# p_loss tensor(0.0055, device='cuda:0')
# c_loss tensor(0.0645, device='cuda:0')
# q_loss tensor(0.0055, device='cuda:0')
# p_loss tensor(0.0055, device='cuda:0')
# c_loss tensor(0.6533, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0055, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0055, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4770, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0054, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0054, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1542, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0052, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0052, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6379, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0051, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0051, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6546, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0050, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0050, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5384, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.5538, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.1841, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.2483, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.3704, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.4081, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.0134, device='cuda:0')
# q_loss tensor(0.0049, device='cuda:0')
# p_loss tensor(0.0049, device='cuda:0')
# c_loss tensor(0.0078, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0050, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0050, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4670, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0047, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0047, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.2189, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0046, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0046, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.8452, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0044, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0044, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2808, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0043, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0043, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2263, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(0.1568, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(1.0189, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(0.8334, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(0.3122, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(0.3116, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(8.5566e-05, device='cuda:0')
# q_loss tensor(0.0042, device='cuda:0')
# p_loss tensor(0.0042, device='cuda:0')
# c_loss tensor(0.3467, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0042, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0042, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1846, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0041, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0041, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2646, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0040, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0040, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2931, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0039, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0039, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2107, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1431, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.0551, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.8289, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.2182, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.1934, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.5282, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.0007, device='cuda:0')
# q_loss tensor(0.0037, device='cuda:0')
# p_loss tensor(0.0037, device='cuda:0')
# c_loss tensor(0.6114, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0038, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5867, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0037, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0037, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2362, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0036, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2609, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0035, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0035, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6101, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0034, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0034, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3550, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(0.3959, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(0.3004, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(0.2071, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(0.2376, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(0.8253, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(9.3150e-05, device='cuda:0')
# q_loss tensor(0.0034, device='cuda:0')
# p_loss tensor(0.0034, device='cuda:0')
# c_loss tensor(0.1377, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0034, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0034, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7339, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1896, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0033, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.0848, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0633, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0032, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2682, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.4039, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.5979, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.1489, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.0092, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.9439, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.1814, device='cuda:0')
# q_loss tensor(0.0031, device='cuda:0')
# p_loss tensor(0.0031, device='cuda:0')
# c_loss tensor(0.1124, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1218, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0031, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2823, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1846, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0030, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2415, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5040, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(0.3972, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(0.0696, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(0.6683, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(0.2863, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(0.0532, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(9.5364e-06, device='cuda:0')
# q_loss tensor(0.0029, device='cuda:0')
# p_loss tensor(0.0029, device='cuda:0')
# c_loss tensor(0.0599, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0029, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0702, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1385, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0028, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0440, device='cuda:0', grad_fn=<NllLossBackward0>)
# ...
# c_loss tensor(0.7168, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.1834, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.0364, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.2903, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.4802, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.9049, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(3.6049, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.2328, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0236, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1121, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3745, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0103, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.6962, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.4156, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.2801, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.9405, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.1630, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.3660, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.0464, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.0433, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2461, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3058, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.7394, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3413, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.6711, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.2386, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.1022, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.3207, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.5921, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.9446, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(9.9889e-05, device='cuda:0')
# q_loss tensor(0.0015, device='cuda:0')
# p_loss tensor(0.0015, device='cuda:0')
# c_loss tensor(0.2711, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0060, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0015, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1608, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0796, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.2512, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.4407, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.7736, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.8173, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.0038, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.2093, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(1.7881e-07, device='cuda:0')
# q_loss tensor(0.0014, device='cuda:0')
# p_loss tensor(0.0014, device='cuda:0')
# c_loss tensor(0.1024, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0606, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2478, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0014, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0049, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2314, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0510, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.7619, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.9672, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.3810, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.3091, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.2226, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(2.6422, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0716, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0002, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2017, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1815, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.3333, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0392, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.0757, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.3314, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(2.2229, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.1510, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.5867, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0012, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0131, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0008, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0562, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0110, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2858, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(1.0823, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.9302, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.4663, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.5713, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.7345, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.3490, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.6155, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.4595, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0182, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1494, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0076, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0242, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0012, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.5627, device='cuda:0')
# q_loss tensor(0.0012, device='cuda:0')
# p_loss tensor(0.0012, device='cuda:0')
# c_loss tensor(0.1080, device='cuda:0')
# q_loss tensor(0.0012, device='cuda:0')
# p_loss tensor(0.0012, device='cuda:0')
# c_loss tensor(0.3583, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.4963, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.9844, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.1202, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0003, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0018, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.4454, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0239, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1786, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.2213, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0901, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.3967, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.2088, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(2.6817, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(1.3357, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.6597, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0002, device='cuda:0')
# q_loss tensor(0.0013, device='cuda:0')
# p_loss tensor(0.0013, device='cuda:0')
# c_loss tensor(0.0044, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.1503, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# c_loss tensor(0.0074, device='cuda:0', grad_fn=<NllLossBackward0>)
# q_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# p_loss tensor(0.0013, device='cuda:0', grad_fn=<MeanBackward0>)
# TrainOutput(global_step=228, training_loss=0.587065102695896, metrics={'train_runtime': 200.8527, 'train_samples_per_second': 35.827, 'train_steps_per_second': 1.135, 'total_flos': 0.0, 'train_loss': 0.587065102695896, 'epoch': 4.0})

# %% [markdown]
# ### Inference

# %%
queries_dev = tsv_to_dict_unqiue(os.path.join('/content/drive/MyDrive/685/data', "queries.dev.small.tsv")) # Changed file path to reflect the actual location in Google Drive
qrels_dev = tsv_to_dict_multiple(os.path.join('/content/drive/MyDrive/685/data', "qrels.dev.small.tsv"), keys = [0, 2]) # Changed file path to reflect the actual location in Google Drive

with open('/content/drive/MyDrive/685/embeddings/train/passage_ids.json') as f: # Changed file path to be an absolute path
    inference_passage_ids = json.load(f)

# %%
from datasets import load_dataset

def encode_texts(model, tokenizer, text_ds, batch_size, verbose=False):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    text_ids = [i['_id'] for i in text_ds]
    dataloader = DataLoader(text_ds, batch_size=batch_size, shuffle=False)
    allemb = []

    model.to(device)
    model.eval()

    with torch.no_grad():
        for batch in tqdm(dataloader):
            prepare_batch = [batch['text'][i] for i in range(len(batch['text']))]
            tokenized_texts = tokenizer.batch_encode_plus(
                prepare_batch,
                max_length=tokenizer.model_max_length,
                padding=True,
                truncation=True,
                return_tensors="pt",
                add_special_tokens=True,
            ).to(device)
            if verbose:
                print("Batch size:", len(batch['text']))
from datasets import load_dataset
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch

def encode_texts(model, tokenizer, text_ds, batch_size, verbose=False):
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    text_ids = [i['_id'] for i in text_ds]
    dataloader = DataLoader(text_ds, batch_size=batch_size, shuffle=False)
    allemb = []

    model.to(device)
    model.eval()

    with torch.no_grad():
        for batch in tqdm(dataloader):
            prepare_batch = [batch['text'][i] for i in range(len(batch['text']))]
            tokenized_texts = tokenizer.batch_encode_plus(
                prepare_batch,
                max_length=tokenizer.model_max_length,
                padding=True,
                truncation=True,
                return_tensors="pt",
                add_special_tokens=True,
            ).to(device)
            if verbose:
                print("Batch size:", len(batch['text']))
                print(f"Tokenized texts shape: {tokenized_texts['input_ids'].shape}")
                print(f"Decode text sample {tokenizer.decode(tokenized_texts['input_ids'][0])}")
            # The change is in the following line: removed attention_mask from the explicit keyword arguments as it is already present in tokenized_texts
            emb = model.get_sparse_rep(input_ids=tokenized_texts['input_ids'], attention_mask=tokenized_texts['attention_mask'])
            allemb.append(emb.cpu())
    allemb = torch.cat(allemb, dim=0)
    allemb = allemb.cpu().numpy()
    return allemb, text_idsmpy()
    return allemb, text_ids

# %%
corpus_ds = Dataset.from_dict({'_id':inference_passage_ids,'text':[passages[_id] for _id in inference_passage_ids]})
queries_ds = Dataset.from_dict({'_id':list(queries_dev.keys()),'text':list(queries_dev.values())})

# %% [markdown]
# ### Top-k Sparsification

# %%
import numpy as np
import os
from tqdm import tqdm
import torch

passage_topk = 1024
save_path = "/content/my_data"
os.makedirs(save_path, exist_ok=True)

embeddings_file = os.path.join(save_path, "passage_sparse_embeddings_topk1024.npy")
ids_file = os.path.join(save_path, "passage_ids.npy")

first_batch = True
device = 'cuda' if torch.cuda.is_available() else 'cpu'

for i in tqdm(range(0, len(corpus_ds), 64)):
    batch = corpus_ds[i:i+64]
    texts = batch['text']
    ids = batch['_id']

    tokenized = tokenizer(texts, padding=True, truncation=True, return_tensors='pt').to(device)

    with torch.no_grad():
        batch_sparse = model.get_sparse_rep(tokenized['input_ids'], tokenized['attention_mask'])

    values, indices = torch.topk(batch_sparse.abs(), k=passage_topk, dim=1)
    sparse_embeddings = torch.zeros_like(batch_sparse)
    sparse_embeddings.scatter_(1, indices, batch_sparse.gather(1, indices))

    sparse_np = sparse_embeddings.cpu().numpy()
    ids_np = np.array(ids)

    if first_batch:
        np.save(embeddings_file, sparse_np)
        np.save(ids_file, ids_np)
        first_batch = False
    else:
        with open(embeddings_file, 'ab') as f:
            np.save(f, sparse_np)
        with open(ids_file, 'ab') as f:
            np.save(f, ids_np)
# Out:
#  91%|█████████▏| 28559/31250 [1:04:36<05:38,  7.96it/s]

# %%
embeddings = []
with open(embeddings_file, 'rb') as f:
    while True:
        try:
            embeddings.append(np.load(f))
        except ValueError:
            break
passage_sparse_embeddings = np.concatenate(embeddings, axis=0)

# %%
# passage_topk = 1024

# passage_sparse_embeddings, passage_ids = encode_texts(model, tokenizer, corpus_ds, batch_size=64)

# # Apply top-k sparsification
# values, indices = torch.topk(passage_sparse_embeddings.abs(), k=passage_topk, dim=1)
# sparse_embeddings = torch.zeros_like(passage_sparse_embeddings)
# sparse_embeddings.scatter_(1, indices, passage_sparse_embeddings.gather(1, indices))

# passage_sparse_embeddings = sparse_embeddings.detach().cpu().numpy()

# %% [markdown]
# ### Inverted Index

# %%
from collections import defaultdict
import heapq


inverted_index = defaultdict(list)
min_weight = 1e-5
for j, doc_id in enumerate(passage_ids):
    doc_embedding = passage_sparse_embeddings[j]
    # Get non-zero indices and their values
    nonzero_indices = np.nonzero(doc_embedding)[0]  # Ensure indices are integers
    for idx in nonzero_indices:
        weight = doc_embedding[idx]
        if weight > min_weight:
            inverted_index[int(idx)].append((doc_id, float(weight)))

 # Sort postings lists by weight for each term
for idx in inverted_index:
    inverted_index[idx] = sorted(inverted_index[idx], key=lambda x: abs(x[1]), reverse=True)

# Convert to more efficient data structure
optimized_index = {
    idx: (
        np.array([doc_id for doc_id, _ in postings], dtype=np.int32),
        np.array([weight for _, weight in postings], dtype=np.float32)
    )
    for idx, postings in inverted_index.items()
}

# %% [markdown]
# ### Search Index

# %%
def search_inverted_index(query_embedding, inverted_index, query_topk=128, min_weight=1e-5):
    scores = defaultdict(float)
    seen_docs = set()

    # Get top-k query dimensions by weight
    weights = [(idx, weight) for idx, weight in enumerate(query_embedding) if abs(weight) > min_weight]
    top_weights = heapq.nlargest(query_topk, weights, key=lambda x: abs(x[1]))

    # Process each query term
    for idx, query_weight in top_weights:
        if idx not in inverted_index:
            continue

        doc_ids, doc_weights = inverted_index[idx]

        # Only process top documents per term
        for doc_id, doc_weight in zip(doc_ids, doc_weights):
            scores[doc_id] += query_weight * doc_weight
            seen_docs.add(doc_id)

    # Use numpy for final scoring
    if seen_docs:
        doc_ids = np.array(list(seen_docs))
        doc_scores = np.array([scores[doc_id] for doc_id in doc_ids])

        # Get top 1000 results efficiently
        top_k = min(1000, len(doc_scores))
        top_indices = np.argpartition(doc_scores, -top_k)[-top_k:]
        top_indices = top_indices[np.argsort(-doc_scores[top_indices])]

        return [(doc_ids[i], doc_scores[i]) for i in top_indices]

    return []

# %% [markdown]
# ### Search

# %%
query_sparse_embeddings, query_ids = encode_texts(model, tokenizer, queries_ds, batch_size=32)

# %%
query_topk = 128

all_results = {}

for i,query_id in enumerate(query_ids):
    query_embedding = query_sparse_embeddings[i].cpu().numpy()[0]
    search_results = search_inverted_index(
                query_embedding,
                optimized_index,
                query_topk=query_topk,
                min_weight=min_weight
            )
    all_results[query_id] = search_results

# %% [markdown]
# ### Metrics

# %%
# Create rank_eval Run and Qrels objects
run = Run()
qrels = Qrels()

# Add results to Run object
for qid in all_results:
    doc_ids = [str(doc_id) for doc_id, score in all_results[qid]]
    scores = [float(score) for _, score in all_results[qid]]
    run.add(qid, doc_ids, scores)

# Add relevance judgments to Qrels object
for qid in qrels_dev:
    qrels.add(qid, [str(doc_id) for doc_id in qrels_dev[qid]], [1] * len(qrels_dev[qid]))

# Evaluate using rank_eval
metrics = ["ndcg@10", "ndcg@100", "ndcg@1000", "recall@10", "recall@100", "recall@1000", "mrr@10"]
results = evaluate(qrels, run, metrics)

metrics = (
    results["mrr@10"],
    {
        '10': results["ndcg@10"],
        '100': results["ndcg@100"],
        '1000': results["ndcg@1000"]
    },
    {
        '10': results["recall@10"],
        '100': results["recall@100"],
        '1000': results["recall@1000"]
    }
)
